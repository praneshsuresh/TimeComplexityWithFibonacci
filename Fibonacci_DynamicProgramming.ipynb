# %% [markdown]
# <a href="https://colab.research.google.com/github/praneshsuresh/TimeComplexityWithFibonacci/blob/main/Fibonacci_DynamicProgramming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Recursive solution

def fib(n):
  if n == 1 or n == 2:
    result = 1
  else:
    result = fib(n-1) + fib(n-2)
  return result

# %%
fib(5)
# Out:
# 5

# %%
fib (10)
# Out:
# 55

# %%
fib (36)
# Out:
# 14930352

# %%
# Memoized solution

def fib_2(n, memo):
    if memo[n] is not None:
        return memo[n]
    if n == 1 or n == 2:
        result = 1
    else:
        result = fib_2(n-1, memo) + fib_2(n-2, memo)
    memo[n] = result
    return result

def fib_memo(n):
    memo = [None] * (n + 1)
    return fib_2(n, memo)

# %%
fib_memo (5)
# Out:
# 5

# %%
fib_memo(36)
# Out:
# 14930352

# %%
fib_memo(50)
# Out:
# 12586269025

# %%
fib_memo(1000)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-31-46b166948401> in <module>()
# ----> 1 fib_memo(1000)
#
# <ipython-input-12-35a24872e704> in fib_memo(n)
#      13 def fib_memo(n):
#      14     memo = [None] * (n + 1)
# ---> 15     return fib_2(n, memo)
#
# <ipython-input-12-35a24872e704> in fib_2(n, memo)
#       7         result = 1
#       8     else:
# ----> 9         result = fib_2(n-1, memo) + fib_2(n-2, memo)
#      10     memo[n] = result
#      11     return result
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-12-35a24872e704> in fib_2(n, memo)
#       7         result = 1
#       8     else:
# ----> 9         result = fib_2(n-1, memo) + fib_2(n-2, memo)
#      10     memo[n] = result
#      11     return result
#
# RecursionError: maximum recursion depth exceeded in comparison

# %%
# Bottom-up solution

def fib_bottom_up(n):
    if n == 1 or n == 2:
        return 1
    bottom_up = [None] * (n+1)
    bottom_up[1] = 1
    bottom_up[2] = 1
    for i in range(3, n+1):
        bottom_up[i] = bottom_up[i-1] + bottom_up[i-2]
    return bottom_up[n]

# %%
fib_bottom_up(50)
# Out:
# 12586269025

# %%
fib_bottom_up(1000)
# Out:
# 43466557686937456435688527675040625802564660517371780402481729089536555417949051890403879840079255169295922593080322634775209689623239873322471161642996440906533187938298969649928516003704476137795166849228875

# %%
fib_bottom_up(25000)
# Out:
# ...
